# %% [markdown]
# <a href="https://colab.research.google.com/github/kumar045/Assignment-For-Filed/blob/main/elevenlabs_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ElevenLabs Python
#
# GitHub: [https://github.com/elevenlabs/elevenlabs-python](https://github.com/elevenlabs/elevenlabs-python)
#
# Website: [https://elevenlabs.io/](https://elevenlabs.io/)

# %%
# !pip install elevenlabs -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.6 MB/s eta 0:00:00
# ...

# %%
from elevenlabs import generate, play, set_api_key

set_api_key("d12d8190ce6eea34eb40ee0ef3b38875") # Check the guide on how to get a free API key: https://docs.elevenlabs.io/authentication/01-xi-api-key

audio = generate(
    text="Hi! I'm the world's most advanced text-to-speech system, made by elevenlabs.",
    voice="Bella"
)

play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from elevenlabs import generate, play

audio = generate(
    text="¡Hola! Mi nombre es Arnold, encantado de conocerte!",
    voice="Arnold",
    model='eleven_multilingual_v1'
)

play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
